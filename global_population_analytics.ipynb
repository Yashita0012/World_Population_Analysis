# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set()

# %%
df = pd.read_csv(r"C:\Users\user\OneDrive\Desktop\csv file folder\Global Population 2023 - Global Population-3.csv")

# %%
df.head(10)
# Out:
#     # Country (or dependency) Population\n(2023) Yearly\nChange  Net\nChange  \
# 0   1                   India      1,428,627,663         0.81 %     11454490
# 1   2                   China      1,425,671,352        -0.02 %      -215985
# 2   3           United States        339,996,563         0.50 %      1706706
# 3   4               Indonesia        277,534,122         0.74 %      2032783
# 4   5                Pakistan        240,485,658         1.98 %      4660796
# 5   6                 Nigeria        223,804,632         2.41 %      5263420
# 6   7                  Brazil        216,422,446         0.52 %      1108948
# 7   8              Bangladesh        172,954,319         1.03 %      1767947
# 8   9                  Russia        144,444,359        -0.19 %      -268955
# 9  10                  Mexico        128,455,567         0.75 %       951442
#
#   Density\n(P/Km²)  Land Area\n(Km²)  Migrants\n(net)  Fert.\nRate  Med.\nAge  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   #                        234 non-null    int64
#  1   Country (or dependency)  234 non-null    object
#  2   Population
# (2023)        234 non-null    object
#  3   Yearly
# Change            234 non-null    object
#  4   Net
# Change               234 non-null    int64
#  5   Density
# (P/Km²)          234 non-null    object
#  6   Land Area
# (Km²)          234 non-null    int64
#  7   Migrants
# (net)           234 non-null    int64
#  8   Fert.
# Rate               233 non-null    float64
#  9   Med.
# Age                 233 non-null    float64
#  10  Urban
# Pop %              234 non-null    object
#  11  World
# Share              234 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 22.1+ KB

# %%
#looking for nan value 
df.isnull().sum()
# Out:
# #                          0
# Country (or dependency)    0
# Population\n(2023)         0
# Yearly\nChange             0
# Net\nChange                0
# Density\n(P/Km²)           0
# Land Area\n(Km²)           0
# Migrants\n(net)            0
# Fert.\nRate                1
# Med.\nAge                  1
# Urban\nPop %               0
# World\nShare               0
# dtype: int64

# %%
df.dropna(inplace= True)

# %%
df.isnull().sum()
# Out:
# #                          0
# Country (or dependency)    0
# Population\n(2023)         0
# Yearly\nChange             0
# Net\nChange                0
# Density\n(P/Km²)           0
# Land Area\n(Km²)           0
# Migrants\n(net)            0
# Fert.\nRate                0
# Med.\nAge                  0
# Urban\nPop %               0
# World\nShare               0
# dtype: int64

# %%
df.tail(10)
# Out:
#        #  Country (or dependency) Population\n(2023) Yearly\nChange  \
# 223  224                    Nauru             12,780         0.88 %
# 224  225          Wallis & Futuna             11,502        -0.60 %
# 225  226                   Tuvalu             11,396         0.74 %
# 226  227         Saint Barthelemy             10,994         0.25 %
# 227  228  Saint Pierre & Miquelon              5,840        -0.38 %
# 228  229             Saint Helena              5,314        -1.12 %
# 229  230               Montserrat              4,386        -0.09 %
# 230  231         Falkland Islands              3,791         0.29 %
# 231  232                     Niue              1,935         0.05 %
# 232  233                  Tokelau              1,893         1.18 %
#
#      Net\nChange Density\n(P/Km²)  Land Area\n(Km²)  Migrants\n(net)  \
# 223          112              639                20             -140
# 224          -70               82               140             -119
# ...

# %%
df.rename(columns= { '#' : "No."}, inplace=True)

# %%
df.head(10)
# Out:
#    No. Country (or dependency) Population\n(2023) Yearly\nChange  Net\nChange  \
# 0    1                   India      1,428,627,663         0.81 %     11454490
# 1    2                   China      1,425,671,352        -0.02 %      -215985
# 2    3           United States        339,996,563         0.50 %      1706706
# 3    4               Indonesia        277,534,122         0.74 %      2032783
# 4    5                Pakistan        240,485,658         1.98 %      4660796
# 5    6                 Nigeria        223,804,632         2.41 %      5263420
# 6    7                  Brazil        216,422,446         0.52 %      1108948
# 7    8              Bangladesh        172,954,319         1.03 %      1767947
# 8    9                  Russia        144,444,359        -0.19 %      -268955
# 9   10                  Mexico        128,455,567         0.75 %       951442
#
#   Density\n(P/Km²)  Land Area\n(Km²)  Migrants\n(net)  Fert.\nRate  Med.\nAge  \
# ...

# %%
df.dtypes
# Out:
# No.                          int64
# Country (or dependency)     object
# Population\n(2023)          object
# Yearly\nChange              object
# Net\nChange                  int64
# Density\n(P/Km²)            object
# Land Area\n(Km²)             int64
# Migrants\n(net)              int64
# Fert.\nRate                float64
# Med.\nAge                  float64
# Urban\nPop %                object
# World\nShare                object
# dtype: object

# %%
df['Population\n(2023)'].astype(str)
# Out:
# 0      1,428,627,663
# 1      1,425,671,352
# 2        339,996,563
# 3        277,534,122
# 4        240,485,658
#            ...
# 228            5,314
# 229            4,386
# 230            3,791
# 231            1,935
# 232            1,893
# Name: Population\n(2023), Length: 233, dtype: object

# %%
df.head(10)
# Out:
#    No. Country (or dependency) Population\n(2023) Yearly\nChange  Net\nChange  \
# 0    1                   India      1,428,627,663         0.81 %     11454490
# 1    2                   China      1,425,671,352        -0.02 %      -215985
# 2    3           United States        339,996,563         0.50 %      1706706
# 3    4               Indonesia        277,534,122         0.74 %      2032783
# 4    5                Pakistan        240,485,658         1.98 %      4660796
# 5    6                 Nigeria        223,804,632         2.41 %      5263420
# 6    7                  Brazil        216,422,446         0.52 %      1108948
# 7    8              Bangladesh        172,954,319         1.03 %      1767947
# 8    9                  Russia        144,444,359        -0.19 %      -268955
# 9   10                  Mexico        128,455,567         0.75 %       951442
#
#   Density\n(P/Km²)  Land Area\n(Km²)  Migrants\n(net)  Fert.\nRate  Med.\nAge  \
# ...

# %%
df['Population\n(2023)'] = df['Population\n(2023)'].astype(str)

# %%
df['Population\n(2023)'] = df['Population\n(2023)'].str.replace(',' , '').astype(int)

# %%
df.head(10)
# Out:
#    No. Country (or dependency)  Population\n(2023) Yearly\nChange  \
# 0    1                   India          1428627663         0.81 %
# 1    2                   China          1425671352        -0.02 %
# 2    3           United States           339996563         0.50 %
# 3    4               Indonesia           277534122         0.74 %
# 4    5                Pakistan           240485658         1.98 %
# 5    6                 Nigeria           223804632         2.41 %
# 6    7                  Brazil           216422446         0.52 %
# 7    8              Bangladesh           172954319         1.03 %
# 8    9                  Russia           144444359        -0.19 %
# 9   10                  Mexico           128455567         0.75 %
#
#    Net\nChange Density\n(P/Km²)  Land Area\n(Km²)  Migrants\n(net)  \
# 0     11454490              481           2973190          -486136
# 1      -215985              152           9388211          -310220
# ...

# %% [markdown]
# TOP 10 MOST POPULATED COUNTRIES

# %%
plt.figure(figsize=(12,8))
plt.bar(x = df['Country (or dependency)'].head(10) , height= df['Population\n(2023)'].head(10) , color = 'r')
plt.title("Top 10 Most Populated Countries" , fontsize = 13)
plt.xlabel("Countries" , fontsize = 12)
plt.ylabel("Popluation Size in Millions ", fontsize = 12)
plt.show()

# %% [markdown]
# TOP 10 LEAST POPULATED COUTRIES

# %%
plt.figure(figsize=(20,8))
plt.bar(x = df['Country (or dependency)'].tail(10) , height= df['Population\n(2023)'].tail(10) , color = 'skyblue')
plt.title("Top 5 Least Populated Countries" , fontsize = 13)
plt.xlabel("Countries" , fontsize = 12)
plt.ylabel("Popluation Size", fontsize = 12)
plt.show()

# %% [markdown]
# HIGHEST NUMBER OF MIGRANTS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 233 entries, 0 to 232
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   No.                      233 non-null    int64
#  1   Country (or dependency)  233 non-null    object
#  2   Population
# (2023)        233 non-null    int32
#  3   Yearly
# Change            233 non-null    object
#  4   Net
# Change               233 non-null    int64
#  5   Density
# (P/Km²)          233 non-null    object
#  6   Land Area
# (Km²)          233 non-null    int64
#  7   Migrants
# (net)           233 non-null    int64
#  8   Fert.
# Rate               233 non-null    float64
#  9   Med.
# Age                 233 non-null    float64
#  10  Urban
# Pop %              233 non-null    object
#  11  World
# Share              233 non-null    object
# dtypes: float64(2), int32(1), int64(4), object(5)
# memory usage: 22.8+ KB

# %%
plt.figure(figsize=(20,10))
plt.bar(x = df['Country (or dependency)'].head(10) , height= df['Migrants\n(net)'].head(10) , color = 'darkgreen', width= 0.5) 
plt.title("Top 50  Most Populated Countries With Highest No. Of Migrants" , fontsize = 13)
plt.xlabel("Countries" , fontsize = 12)
plt.ylabel("Population Of Migrants In Millions", fontsize = 12)
plt.show()

# %%
x = df['Country (or dependency)'].head(10)
y = df['Migrants\n(net)'].head(10)

plt.figure(figsize=(12,8))
plt.plot(x , y , marker = 'o' , linestyle= '-' , color = 'red')
plt.title("Top 10  Most Populated Countries With Highest No. Of Migrants", fontsize = 12)
plt.xlabel("Countries" , fontsize = 12)
plt.ylabel("Population Of Migrants In Millions", fontsize = 12)
plt.show()

# %%
df['Migrants\n(net)'].value_counts()
# Out:
# Migrants\n(net)
#  0         25
# -9999       8
# -2000       6
# -5000       6
# -1000       5
#            ..
#  139991     1
#  321106     1
# -62012      1
#  48997      1
# -60         1
# Name: count, Length: 144, dtype: int64

# %%
x = df['Country (or dependency)'].tail(10)
y = df['Migrants\n(net)'].tail(10)

plt.figure(figsize=(20,10))
plt.plot(x , y , marker = 'o' , linestyle= '-' , color = 'brown')
plt.title("Top 10  least Populated Countries With Highest No. Of Migrants", fontsize = 12)
plt.xlabel("Countries" , fontsize = 12)
plt.ylabel("Population Of Migrants ", fontsize = 12)
plt.show()

# %%
x = df['Country (or dependency)'].head(30)
y = df['Migrants\n(net)'].head(30)

plt.figure(figsize=(35,15))
plt.plot(x , y , marker = 'o' , linestyle= '-' , color = 'r')
plt.title("Top 10  Most Populated Countries With Highest No. Of Migrants", fontsize = 20)
plt.xlabel("Countries" , fontsize = 20)
plt.ylabel("Population Of Migrants In Millions", fontsize = 20)
plt.show()

# %% [markdown]
# Plotting Countries With Highest Number Of Land Area

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 233 entries, 0 to 232
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   No.                      233 non-null    int64
#  1   Country (or dependency)  233 non-null    object
#  2   Population
# (2023)        233 non-null    int32
#  3   Yearly
# Change            233 non-null    object
#  4   Net
# Change               233 non-null    int64
#  5   Density
# (P/Km²)          233 non-null    object
#  6   Land Area
# (Km²)          233 non-null    int64
#  7   Migrants
# (net)           233 non-null    int64
#  8   Fert.
# Rate               233 non-null    float64
#  9   Med.
# Age                 233 non-null    float64
#  10  Urban
# Pop %              233 non-null    object
#  11  World
# Share              233 non-null    object
# dtypes: float64(2), int32(1), int64(4), object(5)
# memory usage: 22.8+ KB

# %%
df['Land Area\n(Km²)'].head(20)
# Out:
# 0      2973190
# 1      9388211
# 2      9147420
# 3      1811570
# 4       770880
# 5       910770
# 6      8358140
# 7       130170
# 8     16376870
# 9      1943950
# 10     1000000
# 11      364555
# 12      298170
# 13      995450
# 14     2267050
# 15      310070
# 16     1628550
# 17      769630
# 18      348560
# 19      510890
# Name: Land Area\n(Km²), dtype: int64

# %%
df['Land Area\n(Km²)'].value_counts()
# Out:
# Land Area\n(Km²)
# 460        3
# 700        2
# 10         2
# 390        2
# 240        2
#           ..
# 155360     1
# 1083300    1
# 27560      1
# 30280      1
# 12170      1
# Name: count, Length: 224, dtype: int64

# %% [markdown]
# TOP COUNTRIES WITH HIGHEST SQUARE KILOMETER AREA (LARGEST AREA OCCUPIED BY WHICH COUNTRY)

# %%
plt.figure(figsize=(20,8))
plt.bar(x = df['Country (or dependency)'].head(15) , height= df['Land Area\n(Km²)'].head(15) , color = 'm')
plt.title("TOP 15 Most Populated Country With Land Area In Million Kilometer Square" , fontsize = 15)
plt.xlabel("Countries" , fontsize = 15)
plt.ylabel("Land Area In  Million Kilometer Square", fontsize = 15)
plt.show()

# %% [markdown]
# TOP LEAST POPULATED  COUNTRIES WITH HIGHEST SQUARE KILOMETER AREA (LARGEST AREA OCCUPIED BY WHICH LEAST POPULATED COUNTRY)

# %%
plt.figure(figsize=(20,8))
plt.bar(x = df['Country (or dependency)'].tail(10) , height= df['Land Area\n(Km²)'].tail(10) , color = 'orange')
plt.title("TOP 10 Least Populated Country With Land Area In Kilometer Square" , fontsize = 15)
plt.xlabel("Countries" , fontsize = 14)
plt.ylabel("Land Area", fontsize = 14)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 233 entries, 0 to 232
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   No.                      233 non-null    int64
#  1   Country (or dependency)  233 non-null    object
#  2   Population
# (2023)        233 non-null    int32
#  3   Yearly
# Change            233 non-null    object
#  4   Net
# Change               233 non-null    int64
#  5   Density
# (P/Km²)          233 non-null    object
#  6   Land Area
# (Km²)          233 non-null    int64
#  7   Migrants
# (net)           233 non-null    int64
#  8   Fert.
# Rate               233 non-null    float64
#  9   Med.
# Age                 233 non-null    float64
#  10  Urban
# Pop %              233 non-null    object
#  11  World
# Share              233 non-null    object
# dtypes: float64(2), int32(1), int64(4), object(5)
# memory usage: 22.8+ KB

# %%
df.head(50)
# Out:
#     No. Country (or dependency)  Population\n(2023) Yearly\nChange  \
# 0     1                   India          1428627663         0.81 %
# 1     2                   China          1425671352        -0.02 %
# 2     3           United States           339996563         0.50 %
# 3     4               Indonesia           277534122         0.74 %
# 4     5                Pakistan           240485658         1.98 %
# 5     6                 Nigeria           223804632         2.41 %
# 6     7                  Brazil           216422446         0.52 %
# 7     8              Bangladesh           172954319         1.03 %
# 8     9                  Russia           144444359        -0.19 %
# 9    10                  Mexico           128455567         0.75 %
# 10   11                Ethiopia           126527060         2.55 %
# 11   12                   Japan           123294513        -0.53 %
# 12   13             Philippines           117337368         1.54 %
# ...

# %%
df['Density\n(P/Km²)'] = df['Density\n(P/Km²)'].astype(str)

# %%
df['Density\n(P/Km²)']  =df['Density\n(P/Km²)'].str.replace(',' , '').astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 233 entries, 0 to 232
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   No.                      233 non-null    int64
#  1   Country (or dependency)  233 non-null    object
#  2   Population
# (2023)        233 non-null    int32
#  3   Yearly
# Change            233 non-null    object
#  4   Net
# Change               233 non-null    int64
#  5   Density
# (P/Km²)          233 non-null    int32
#  6   Land Area
# (Km²)          233 non-null    int64
#  7   Migrants
# (net)           233 non-null    int64
#  8   Fert.
# Rate               233 non-null    float64
#  9   Med.
# Age                 233 non-null    float64
#  10  Urban
# Pop %              233 non-null    object
#  11  World
# Share              233 non-null    object
# dtypes: float64(2), int32(2), int64(4), object(4)
# memory usage: 21.8+ KB

# %%
df['Med.\nAge'].head(25)
# Out:
# 0     28.0
# 1     39.0
# 2     38.0
# 3     30.0
# 4     21.0
# 5     17.0
# 6     34.0
# 7     27.0
# 8     39.0
# 9     30.0
# 10    19.0
# 11    49.0
# 12    25.0
# 13    24.0
# 14    16.0
# 15    33.0
# 16    33.0
# 17    32.0
# 18    45.0
# 19    40.0
# 20    40.0
# 21    17.0
# 22    42.0
# 23    28.0
# 24    48.0
# Name: Med.\nAge, dtype: float64

# %%
median_age_grp = [ '10-20' , '21-30' , '31-40' , '41-50' , '51-60 ' , '61-70' , '71-80' , '81-90' , '91-100', '101 -110','111-120']
df['median_age_grp']  = pd.cut(df['Med.\nAge'] , bins = np.arange(10,121,10), labels=median_age_grp, right=True)
df
# Out:
#      No. Country (or dependency)  Population\n(2023) Yearly\nChange  \
# 0      1                   India          1428627663         0.81 %
# 1      2                   China          1425671352        -0.02 %
# 2      3           United States           339996563         0.50 %
# 3      4               Indonesia           277534122         0.74 %
# 4      5                Pakistan           240485658         1.98 %
# ..   ...                     ...                 ...            ...
# 228  229            Saint Helena                5314        -1.12 %
# 229  230              Montserrat                4386        -0.09 %
# 230  231        Falkland Islands                3791         0.29 %
# 231  232                    Niue                1935         0.05 %
# 232  233                 Tokelau                1893         1.18 %
#
#      Net\nChange  Density\n(P/Km²)  Land Area\n(Km²)  Migrants\n(net)  \
# 0       11454490               481           2973190          -486136
# ...

# %%
df.head(20)
# Out:
#     No. Country (or dependency)  Population\n(2023) Yearly\nChange  \
# 0     1                   India          1428627663         0.81 %
# 1     2                   China          1425671352        -0.02 %
# 2     3           United States           339996563         0.50 %
# 3     4               Indonesia           277534122         0.74 %
# 4     5                Pakistan           240485658         1.98 %
# 5     6                 Nigeria           223804632         2.41 %
# 6     7                  Brazil           216422446         0.52 %
# 7     8              Bangladesh           172954319         1.03 %
# 8     9                  Russia           144444359        -0.19 %
# 9    10                  Mexico           128455567         0.75 %
# 10   11                Ethiopia           126527060         2.55 %
# 11   12                   Japan           123294513        -0.53 %
# 12   13             Philippines           117337368         1.54 %
# ...

# %% [markdown]
# THE MOST POPULATED COUNTRY WITH THEIR MEDIAN AGE GROUP

# %%
age1 = df['median_age_grp'].value_counts
age1
# Out:
# <bound method IndexOpsMixin.value_counts of 0       21-30
# 1       31-40
# 2       31-40
# 3       21-30
# 4       21-30
#         ...
# 228    51-60
# 229     41-50
# 230     31-40
# 231     31-40
# 232     21-30
# Name: median_age_grp, Length: 233, dtype: category
# Categories (11, object): ['10-20' < '21-30' < '31-40' < '41-50' ... '81-90' < '91-100' < '101 -110' < '111-120']>

# %% [markdown]
# TOP 10 MOST POPULATED COUNTRIES WITH THEIR MEDIAN AGE

# %%
x = df['Country (or dependency)'].head(10)
y = df['Med.\nAge'].head(10)

plt.figure(figsize=(12,8))
plt.plot(x , y , marker = 'o' , linestyle= '-' , color = 'purple')
plt.title("Top 10  Most Populated Countries With Median Age Population", fontsize = 12 )
plt.xlabel("Countries" , fontsize = 12)
plt.ylabel("Median Age Of Peoples", fontsize = 12)
plt.show()

# %%
x = df['Country (or dependency)'].head(30)
y = df['Med.\nAge'].head(30)

plt.figure(figsize=(30,12))
plt.plot(x , y , marker = 'o' , linestyle= '-' , color = 'b')
plt.title("Top 30  Most Populated Countries With Median Age Population", fontsize = 12 )
plt.xlabel("Countries" , fontsize = 12)
plt.ylabel("Median Age Of Peoples", fontsize = 12)
plt.show()

# %%
agev= df['median_age_grp'].value_counts()
agev
# Out:
# median_age_grp
# 31-40       76
# 21-30       64
# 41-50       46
# 10-20       45
# 51-60        2
# 61-70        0
# 71-80        0
# 81-90        0
# 91-100       0
# 101 -110     0
# 111-120      0
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,18))
plt.pie(agev, labels = ['31-40' ,'21-30', '41-50 ' , '10-20' , '51-60', '61-70 ', '71-80 ' , '81-90' , '91-100' , '101 -110' , '111-120'] , autopct = '%1.1f%%')
plt.title('AGE  GROUP SHARE TO WORLD POPULATION' , fontsize = 12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# MOST POPULATED COUNTRY POPULATION SHARE TO THE WORLD

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 233 entries, 0 to 232
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   No.                      233 non-null    int64
#  1   Country (or dependency)  233 non-null    object
#  2   Population
# (2023)        233 non-null    int32
#  3   Yearly
# Change            233 non-null    object
#  4   Net
# Change               233 non-null    int64
#  5   Density
# (P/Km²)          233 non-null    int32
#  6   Land Area
# (Km²)          233 non-null    int64
#  7   Migrants
# (net)           233 non-null    int64
#  8   Fert.
# Rate               233 non-null    float64
#  9   Med.
# Age                 233 non-null    float64
#  10  Urban
# Pop %              233 non-null    object
#  11  World
# Share              233 non-null    object
#  12  median_age_grp           233 non-null    category
# ...

# %%
df['World\nShare'].head(20)
# Out:
# 0     17.76 %
# 1     17.72 %
# 2      4.23 %
# 3      3.45 %
# 4      2.99 %
# 5      2.78 %
# 6      2.69 %
# 7      2.15 %
# 8      1.80 %
# 9      1.60 %
# 10     1.57 %
# 11     1.53 %
# 12     1.46 %
# 13     1.40 %
# 14     1.27 %
# 15     1.23 %
# 16     1.11 %
# 17     1.07 %
# 18     1.04 %
# 19     0.89 %
# Name: World\nShare, dtype: object

# %%
df['World\nShare'].astype(str)
# Out:
# 0      17.76 %
# 1      17.72 %
# 2       4.23 %
# 3       3.45 %
# 4       2.99 %
#         ...
# 228     0.00 %
# 229     0.00 %
# 230     0.00 %
# 231     0.00 %
# 232     0.00 %
# Name: World\nShare, Length: 233, dtype: object

# %%
worldshare = df['World\nShare'].value_counts()

# %%
worldshare
# Out:
# World\nShare
# 0.00 %     55
# 0.01 %     19
# 0.03 %     11
# 0.07 %      9
# 0.02 %      9
#            ..
# 0.30 %      1
# 1.07 %      1
# 0.27 %      1
# 0.75 %      1
# 17.76 %     1
# Name: count, Length: 69, dtype: int64

# %%
plt.figure(figsize=(20,8))
plt.bar(x = df['Country (or dependency)'].head(10) , height= worldshare.head(10) , color = 'purple')
plt.title("TOP 10 Most  Populated Country Contribution To World Population" , fontsize = 15)
plt.xlabel("Countries" , fontsize = 14)
plt.ylabel("World Share Population Percentage %", fontsize = 14)
plt.show()

# %%
country = df['Country (or dependency)'].value_counts
country
# Out:
# <bound method IndexOpsMixin.value_counts of 0                 India
# 1                 China
# 2         United States
# 3             Indonesia
# 4              Pakistan
#              ...
# 228        Saint Helena
# 229          Montserrat
# 230    Falkland Islands
# 231                Niue
# 232             Tokelau
# Name: Country (or dependency), Length: 233, dtype: object>

# %% [markdown]
# TOP 10 MOST POPULATED COUNTRY WITH THEIR FERTILITY RATES

# %%
df['Fert.\nRate'].head(10)
# Out:
# 0    2.0
# 1    1.2
# 2    1.7
# 3    2.1
# 4    3.3
# 5    5.1
# 6    1.6
# 7    1.9
# 8    1.5
# 9    1.8
# Name: Fert.\nRate, dtype: float64

# %%
x = df['Country (or dependency)'].head(10)
y = df['Fert.\nRate'].head(10)

plt.figure(figsize=(12,8))
plt.plot(x , y , marker = 'o' , linestyle= '-' , color = 'green')
plt.title("Top 10  Most Populated Countries With Highest Fertility Rate", fontsize = 20)
plt.xlabel("Countries" , fontsize = 20)
plt.ylabel("Population Of Migrants In Millions", fontsize = 20)
plt.show()

# %%
x = df['Country (or dependency)'].head(30)
y = df['Fert.\nRate'].head(30)

plt.figure(figsize=(35,15))
plt.plot(x , y , marker = 'o' , linestyle= '-', color = 'darkgreen')
plt.title("Top 30  Most Populated Countries With Highest Fertility Rate", fontsize = 20)
plt.xlabel("Countries" , fontsize = 20)
plt.ylabel("Population Of Migrants In Millions", fontsize = 20)
plt.show()
